# %%
import pandas as pd
s = pd.Series([10,20,30,40,50])
s1 = pd.Series([10,20,30,40,50],index=['a','b','c','d','e'])
s2 = pd.Series({'a':10,'b':20,'c':30 ,'d':40,'e':50 })

# series常见属性:index , values ,size ,dtype ,shape
s2.index.tolist()
s2.values.tolist()
s2.size # 元素个数
s2.dtype # 数据类型
s2.shape # 维度
# Out:
# (5,)
