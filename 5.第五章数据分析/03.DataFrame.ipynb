# %%
import pandas as pd
# 字典创建DataFrame
df1 = pd.DataFrame({
    '姓名': ['张三', '李四', '王五', '赵六', '小王1', '小王2', '小王3'],
    '语文': [80, 75, 90, 85, 78, 88, 90],
    '数学': [75, 80, 85, 90, 78, 88, 90],
    '英语': [85, 90, 88, 92, 85, 89, 91]
})
# 列表嵌套列表创建DataFrame
df2 = pd.DataFrame([
    ('张三', 80, 75, 85),
    ('李四', 75, 80, 90),
    ('王五', 90, 85, 88)
], columns=['姓名', 'c', '数学', '英语'],index=['a', 'b', 'c'])

df = pd.DataFrame()
# dateframe常见属性:index:索引 ,columns:列表名 , value:值 ,size:数量 ,dtypes:每列数据类型 , shape:行数列数(维度)
# df2.index.tolist()
# df2.columns.tolist()
# df1.values.tolist()
# df2.size :12
df2.shape
df2['c']
# Out:
# a    80
# b    75
# c    90
# Name: c, dtype: int64
